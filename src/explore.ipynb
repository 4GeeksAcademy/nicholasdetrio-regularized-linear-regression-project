# %% [markdown]
# # Explore here

# %%
# use heart disease_numbers as your y to predict

import pandas as pd

total_data = pd.read_csv("https://raw.githubusercontent.com/4GeeksAcademy/regularized-linear-regression-project-tutorial/main/demographic_health_data.csv", sep = ",")
total_data.head()
# Out:
#    fips  TOT_POP    0-9  0-9 y/o % of total pop  19-Oct  \
# 0  1001    55601   6787               12.206615    7637
# 1  1003   218022  24757               11.355276   26913
# 2  1005    24881   2732               10.980266    2960
# 3  1007    22400   2456               10.964286    2596
# 4  1009    57840   7095               12.266598    7570
#
#    10-19 y/o % of total pop  20-29  20-29 y/o % of total pop  30-39  \
# 0                 13.735364   6878                 12.370281   7089
# 1                 12.344167  23579                 10.814964  25213
# 2                 11.896628   3268                 13.134520   3201
# 3                 11.589286   3029                 13.522321   3113
# 4                 13.087828   6742                 11.656293   6884
#
#    30-39 y/o % of total pop  ...  COPD_number  diabetes_prevalence  \
# 0                 12.749771  ...         3644                 12.9
# 1                 11.564429  ...        14692                 12.0
# ...

# %%
# Obtain dimensions of dataframe
# (# rows, # coluns)
total_data.shape
# Out:
# (3140, 108)

# %%
total_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3140 entries, 0 to 3139
# Columns: 108 entries, fips to Urban_rural_code
# dtypes: float64(61), int64(45), object(2)
# memory usage: 2.6+ MB

# %%
total_data.columns
# Out:
# Index(['fips', 'TOT_POP', '0-9', '0-9 y/o % of total pop', '19-Oct',
#        '10-19 y/o % of total pop', '20-29', '20-29 y/o % of total pop',
#        '30-39', '30-39 y/o % of total pop',
#        ...
#        'COPD_number', 'diabetes_prevalence', 'diabetes_Lower 95% CI',
#        'diabetes_Upper 95% CI', 'diabetes_number', 'CKD_prevalence',
#        'CKD_Lower 95% CI', 'CKD_Upper 95% CI', 'CKD_number',
#        'Urban_rural_code'],
#       dtype='object', length=108)

# %%
# Get the total missing values for each column
missing_values_per_column = total_data.isnull().sum(axis=0)

#only print if there is a missing/null value in a column
print("Total missing values for each column:")
for column, count in missing_values_per_column.items():
    if count != 0:
        print(f"{column}: {count}")
# Out:
# Total missing values for each column:

# %%
missing_proportion = round(total_data.isnull().sum(axis=0) / len(total_data), 4) == 0

print("Proportion of missing values for each column:")
print(missing_proportion)
# Out:
# Proportion of missing values for each column:
# fips                      True
# TOT_POP                   True
# 0-9                       True
# 0-9 y/o % of total pop    True
# 19-Oct                    True
#                           ...
# CKD_prevalence            True
# CKD_Lower 95% CI          True
# CKD_Upper 95% CI          True
# CKD_number                True
# Urban_rural_code          True
# Length: 108, dtype: bool

# %%
# Get the total number of duplicate rows
duplicate_rows_count = total_data.duplicated().sum()

print("Total duplicate rows:")
if duplicate_rows_count != 0:
    print(duplicate_rows_count)
# Out:
# Total duplicate rows:

# %%
#change dataframe to print all columns. did not work on total_data.columns
pd.set_option('display.max_columns', None)
total_data
# Out:
#        fips  TOT_POP    0-9  0-9 y/o % of total pop  19-Oct  \
# 0      1001    55601   6787               12.206615    7637
# 1      1003   218022  24757               11.355276   26913
# 2      1005    24881   2732               10.980266    2960
# 3      1007    22400   2456               10.964286    2596
# 4      1009    57840   7095               12.266598    7570
# ...     ...      ...    ...                     ...     ...
# 3135  56037    43051   6104               14.178532    6326
# 3136  56039    23081   2384               10.328842    2185
# 3137  56041    20299   3121               15.375142    3205
# 3138  56043     7885    858               10.881420    1113
# 3139  56045     6967    780               11.195637     779
#
#       10-19 y/o % of total pop  20-29  20-29 y/o % of total pop  30-39  \
# 0                    13.735364   6878                 12.370281   7089
# 1                    12.344167  23579                 10.814964  25213
# ...

# %%
"""
columns_to_remove = ["0-9 y/o % of total pop","10-19 y/o % of total pop", "20-29 y/o % of total pop", "30-39 y/o % of total pop", "40-49 y/o % of total pop", "50-59 y/o % of total pop",
                     "60-69 y/o % of total pop","70-79 y/o % of total pop","80+ y/o % of total pop", "% White-alone",  "% Black-alone", "% NA/AI-alone", "% Asian-alone", "% Hawaiian/PI-alone", 
                     "% Two or more races", "Percent of adults with less than a high school diploma 2014-18", "Percent of adults with a high school diploma only 2014-18", 
                     "Percent of adults completing some college or associate's degree 2014-18", "Percent of adults with a bachelor's degree or higher 2014-18", "Med_HH_Income_Percent_of_State_Total_2018", 
                     "Percent of Population Aged 60+"]

for column in columns_to_remove:
    try:
        total_data = total_data.drop(column, axis=1)
    except:
        print(f"Column {column} was already removed.")

total_data.head()

"""
# Out:
# '\ncolumns_to_remove = ["0-9 y/o % of total pop","10-19 y/o % of total pop", "20-29 y/o % of total pop", "30-39 y/o % of total pop", "40-49 y/o % of total pop", "50-59 y/o % of total pop",\n                     "60-69 y/o % of total pop","70-79 y/o % of total pop","80+ y/o % of total pop", "% White-alone",  "% Black-alone", "% NA/AI-alone", "% Asian-alone", "% Hawaiian/PI-alone", \n                     "% Two or more races", "Percent of adults with less than a high school diploma 2014-18", "Percent of adults with a high school diploma only 2014-18", \n                     "Percent of adults completing some college or associate\'s degree 2014-18", "Percent of adults with a bachelor\'s degree or higher 2014-18", "Med_HH_Income_Percent_of_State_Total_2018", \n                     "Percent of Population Aged 60+"]\n\nfor column in columns_to_remove:\n    try:\n        total_data = total_data.drop(column, axis=1)\n    except:\n        print(f"Column {column} was already removed.")\n\ntota
# ...

# %% [markdown]
# List of all the columns i want to remove at first. Mostly ones based on percentage because the amounts are there to calculate already. n
#
# "0-9 y/o % of total pop","10-19 y/o % of total pop", "20-29 y/o % of total pop", "30-39 y/o % of total pop", "40-49 y/o % of total pop", "50-59 y/o % of total pop","60-69 y/o % of total pop","70-79 y/o % of total pop","80+ y/o % of total pop", "% White-alone",  "% Black-alone", "% NA/AI-alone", "% Asian-alone", "% Hawaiian/PI-alone", "% Two or more races", "Percent of adults with less than a high school diploma 2014-18", "Percent of adults with a high school diploma only 2014-18", "Percent of adults completing some college or associate's degree 2014-18", "Percent of adults with a bachelor's degree or higher 2014-18", "Med_HH_Income_Percent_of_State_Total_2018", "Percent of Population Aged 60+"

# %% [markdown]
# Here's a list of all the columns, I used find and replace in excel to convert the comma (,) to a (", ") in order to use in a formula
#
# "fips", "TOT_POP", "0-9", "0-9 y/o % of total pop", "19-Oct", "10-19 y/o % of total pop", "20-29", "20-29 y/o % of total pop", "30-39", "30-39 y/o % of total pop", "40-49", "40-49 y/o % of total pop", "50-59", "50-59 y/o % of total pop", "60-69", "60-69 y/o % of total pop", "70-79", "70-79 y/o % of total pop", "80+", "80+ y/o % of total pop", "White-alone pop", "% White-alone", "Black-alone pop", "% Black-alone", "Native American/American Indian-alone pop", "% NA/AI-alone", "Asian-alone pop", "% Asian-alone", "Hawaiian/Pacific Islander-alone pop", "% Hawaiian/PI-alone", "Two or more races pop", "% Two or more races", "POP_ESTIMATE_2018", "N_POP_CHG_2018", "GQ_ESTIMATES_2018", "R_birth_2018", "R_death_2018", "R_NATURAL_INC_2018", "R_INTERNATIONAL_MIG_2018", "R_DOMESTIC_MIG_2018", "R_NET_MIG_2018", "Less than a high school diploma 2014-18", "High school diploma only 2014-18", "Some college or associate's degree 2014-18", "Bachelor's degree or higher 2014-18", "Percent of adults with less than a high school diploma 2014-18", "Percent of adults with a high school diploma only 2014-18", "Percent of adults completing some college or associate's degree 2014-18", "Percent of adults with a bachelor's degree or higher 2014-18", "POVALL_2018", "PCTPOVALL_2018", "PCTPOV017_2018", "PCTPOV517_2018", "MEDHHINC_2018", "CI90LBINC_2018", "CI90UBINC_2018", "Civilian_labor_force_2018", "Employed_2018", "Unemployed_2018", "Unemployment_rate_2018", "Median_Household_Income_2018", "Med_HH_Income_Percent_of_State_Total_2018", "Active Physicians per 100000 Population 2018 (AAMC)", "Total Active Patient Care Physicians per 100000 Population 2018 (AAMC)", "Active Primary Care Physicians per 100000 Population 2018 (AAMC)", "Active Patient Care Primary Care Physicians per 100000 Population 2018 (AAMC)", "Active General Surgeons per 100000 Population 2018 (AAMC)", "Active Patient Care General Surgeons per 100000 Population 2018 (AAMC)", "Total nurse practitioners (2019)", "Total physician assistants (2019)", "Total Hospitals (2019)", "Internal Medicine Primary Care (2019)", "Family Medicine/General Practice Primary Care (2019)", "Total Specialist Physicians (2019)", "ICU Beds_x", "Total Population", "Population Aged 60+", "Percent of Population Aged 60+", "COUNTY_NAME", "STATE_NAME", "STATE_FIPS", "CNTY_FIPS", "county_pop2018_18 and older", "anycondition_prevalence", "anycondition_Lower 95% CI", "anycondition_Upper 95% CI", "anycondition_number", "Obesity_prevalence", "Obesity_Lower 95% CI", "Obesity_Upper 95% CI", "Obesity_number", "Heart disease_prevalence", "Heart disease_Lower 95% CI", "Heart disease_Upper 95% CI", "Heart disease_number", "COPD_prevalence", "COPD_Lower 95% CI", "COPD_Upper 95% CI", "COPD_number", "diabetes_prevalence", "diabetes_Lower 95% CI", "diabetes_Upper 95% CI", "diabetes_number", "CKD_prevalence", "CKD_Lower 95% CI", "CKD_Upper 95% CI", "CKD_number", "Urban_rural_code"

# %%
total_data.shape
# Out:
# (3140, 108)

# %%
total_data.dtypes
# Out:
# fips                        int64
# TOT_POP                     int64
# 0-9                         int64
# 0-9 y/o % of total pop    float64
# 19-Oct                      int64
#                            ...
# CKD_prevalence            float64
# CKD_Lower 95% CI          float64
# CKD_Upper 95% CI          float64
# CKD_number                  int64
# Urban_rural_code            int64
# Length: 108, dtype: object

# %%
total_data['COUNTY_NAME'].dtypes
# Out:
# dtype('O')

# %%
# Making 3 new columns that are the numeric representation of the original categorical column
total_data['COUNTY_NAME_n'] = pd.factorize(total_data['COUNTY_NAME'])[0]
total_data['STATE_NAME_n'] = pd.factorize(total_data['STATE_NAME'])[0]
#total_data['room_type_n'] = pd.factorize(total_data['room_type'])[0]

total_data.head()
# Out:
#    fips  TOT_POP    0-9  0-9 y/o % of total pop  19-Oct  \
# 0  1001    55601   6787               12.206615    7637
# 1  1003   218022  24757               11.355276   26913
# 2  1005    24881   2732               10.980266    2960
# 3  1007    22400   2456               10.964286    2596
# 4  1009    57840   7095               12.266598    7570
#
#    10-19 y/o % of total pop  20-29  20-29 y/o % of total pop  30-39  \
# 0                 13.735364   6878                 12.370281   7089
# 1                 12.344167  23579                 10.814964  25213
# 2                 11.896628   3268                 13.134520   3201
# 3                 11.589286   3029                 13.522321   3113
# 4                 13.087828   6742                 11.656293   6884
#
#    30-39 y/o % of total pop  40-49  40-49 y/o % of total pop  50-59  \
# 0                 12.749771   7582                 13.636445   7738
# 1                 11.564429  27338                 12.539102  29986
# ...

# %%
# Drop the original categorical columns
total_data = total_data.drop(['COUNTY_NAME', 'STATE_NAME'], axis=1)
total_data.head()
# Out:
#    fips  TOT_POP    0-9  0-9 y/o % of total pop  19-Oct  \
# 0  1001    55601   6787               12.206615    7637
# 1  1003   218022  24757               11.355276   26913
# 2  1005    24881   2732               10.980266    2960
# 3  1007    22400   2456               10.964286    2596
# 4  1009    57840   7095               12.266598    7570
#
#    10-19 y/o % of total pop  20-29  20-29 y/o % of total pop  30-39  \
# 0                 13.735364   6878                 12.370281   7089
# 1                 12.344167  23579                 10.814964  25213
# 2                 11.896628   3268                 13.134520   3201
# 3                 11.589286   3029                 13.522321   3113
# 4                 13.087828   6742                 11.656293   6884
#
#    30-39 y/o % of total pop  40-49  40-49 y/o % of total pop  50-59  \
# 0                 12.749771   7582                 13.636445   7738
# 1                 11.564429  27338                 12.539102  29986
# ...

# %%
# X represents all features excluding the target
X = total_data # A dataframe (double brackets)
X = total_data.drop(columns=['Heart disease_number'])

# y contains our target feature
y = total_data['Heart disease_number'] # A series (single brackets)

# %%
X.head()
# Out:
#    fips  TOT_POP    0-9  0-9 y/o % of total pop  19-Oct  \
# 0  1001    55601   6787               12.206615    7637
# 1  1003   218022  24757               11.355276   26913
# 2  1005    24881   2732               10.980266    2960
# 3  1007    22400   2456               10.964286    2596
# 4  1009    57840   7095               12.266598    7570
#
#    10-19 y/o % of total pop  20-29  20-29 y/o % of total pop  30-39  \
# 0                 13.735364   6878                 12.370281   7089
# 1                 12.344167  23579                 10.814964  25213
# 2                 11.896628   3268                 13.134520   3201
# 3                 11.589286   3029                 13.522321   3113
# 4                 13.087828   6742                 11.656293   6884
#
#    30-39 y/o % of total pop  40-49  40-49 y/o % of total pop  50-59  \
# 0                 12.749771   7582                 13.636445   7738
# 1                 11.564429  27338                 12.539102  29986
# ...

# %%
y
# Out:
# 0        3345
# 1       13414
# 2        2159
# 3        1533
# 4        4101
#         ...
# 3135     1862
# 3136      981
# 3137     1034
# 3138      500
# 3139      471
# Name: Heart disease_number, Length: 3140, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
nrows, ncolumns = total_data.shape

print(f"Our entire dataset has {nrows} rows.")
print(f"Our training set should have 80% of our data so it should have {int(0.8*nrows)} rows.")
print(f"Our test set should have 20% of our data so it should have {int(0.2*nrows)} rows.")
# Out:
# Our entire dataset has 3140 rows.
# Our training set should have 80% of our data so it should have 2512 rows.
# Our test set should have 20% of our data so it should have 628 rows.

# %%
X_train
# Out:
#        fips  TOT_POP    0-9  0-9 y/o % of total pop  19-Oct  \
# 2240  41069     1366    117                8.565154     118
# 9      1019    26032   2554                9.811002    2981
# 164    5111    23974   3194               13.322766    3089
# 1839  36027   293718  27925                9.507419   37144
# 1636  30081    43172   4182                9.686834    4940
# ...     ...      ...    ...                     ...     ...
# 1567  29173    10212   1062               10.399530    1293
# 3095  55099    13397   1206                9.002015    1472
# 1955  37135   146027  14406                9.865299   21975
# 1375  27127    15249   2026               13.286117    2082
# 3094  55097    70942   7253               10.223845    9680
#
#       10-19 y/o % of total pop  20-29  20-29 y/o % of total pop  30-39  \
# 2240                  8.638360     97                  7.101025    116
# 9                    11.451291   2852                 10.955747   2504
# ...

# %%
y_train
# Out:
# 2240      144
# 9        2282
# 164      1871
# 1839    15968
# 1636     3132
#         ...
# 1567      732
# 3095     1038
# 1955     6571
# 1375      913
# 3094     3574
# Name: Heart disease_number, Length: 2512, dtype: int64

# %%
X_test
# Out:
#        fips  TOT_POP    0-9  0-9 y/o % of total pop  19-Oct  \
# 1165  22109   111021  15409               13.879356   15133
# 1031  21081    25121   3632               14.458023    3669
# 1422  28047   206650  27283               13.202516   27883
# 275    8065     7824    836               10.685072     916
# 992   21003    21122   2638               12.489348    2703
# ...     ...      ...    ...                     ...     ...
# 719   18049    20092   2485               12.368107    2673
# 237    6107   465861  78108               16.766375   78615
# 1493  29025     9108   1084               11.901625    1299
# 2595  48149    25349   2660               10.493511    2954
# 1812  35035    66781   8949               13.400518    8234
#
#       10-19 y/o % of total pop  20-29  20-29 y/o % of total pop  30-39  \
# 1165                 13.630755  14635                 13.182191  15154
# 1031                 14.605310   3175                 12.638828   3051
# ...

# %%
y_test
# Out:
# 1165     7381
# 1031     1679
# 1422    12522
# 275       400
# 992      1707
#         ...
# 719      1322
# 237     22248
# 1493      653
# 2595     2070
# 1812     3853
# Name: Heart disease_number, Length: 628, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
print(f"Intercep (a): {model.intercept_}")
print(f"Coefficients: {model.coef_}")
# Out:
# Intercep (a): [ 1.71021756e-11  1.94460154e-10  9.15924867e-11 ... -8.41791866e-10
#  -9.25507871e-10 -8.88537975e-10]
# Coefficients: [[ 8.94079322e-06 -1.57187964e-05 -1.88000575e-06 ...  5.31638303e-10
#    4.36837119e-07  8.34121581e-09]
#  [-1.41909604e-06 -1.24857383e-05 -1.50614111e-06 ...  5.10969190e-10
#    1.92476727e-08 -2.15187404e-09]
#  [ 1.12142287e-05 -1.43967756e-05 -1.72585497e-06 ...  9.23454187e-10
#    4.85652629e-07  1.03154891e-08]
#  ...
#  [-1.88279904e-05  2.52461914e-05  2.55569469e-05 ... -2.77967722e-09
#   -5.90342109e-07 -1.58058885e-08]
#  [-2.74112593e-05  6.75621201e-06 -4.82068896e-06 ... -2.79830277e-09
#   -5.97188204e-07 -2.38563192e-08]
#  [-2.40528459e-05  8.71134603e-06 -5.82229440e-06 ... -2.54661982e-09
#   -5.37089787e-07 -2.06266680e-08]]

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([  4866,   1678,  15076,     45,   1678,   1842,    160,   1050,
#          1678,    219,    160,    792,   3605,    792,    594,   4301,
#           188,   4397,  10308,   4397,  23497,   2778,   3605,    792,
#          4301,   6026,   1842,  15192,   1842,   2778,   2778,   1678,
#          1842,   4397,   1453,   2778,  19213,   3605,   2778,   9341,
#         48398,   3605,  16223,     52,   1842,   2778,    260,   6919,
#           160,   2778,   3605,    260,   1678,   3605,    908,   1678,
#         26086,  11403,  14559,   4397,     45,     45,    260,     52,
#          1191,     45,    913,     45,    522,  16223,    792,  12652,
#          3605,    792,   1678,     45,   6026,   6919,   1174,     52,
#            52,   1842,     45,     52,  40301,   6919,    219,    260,
#          7011,   1191,    260,   6919,   1174,   3605,    522,  12626,
#          1191,   3605,   4397,    908,   1842,     52,   4301,     45,
# ...

# %%
from sklearn.metrics import mean_squared_error, r2_score

print(f"MSE: {mean_squared_error(y_test, y_pred)}")
print(f"R2 Score: {r2_score(y_test, y_pred)}")
# Out:
# MSE: 53756897.60828026
# R2 Score: 0.7675608217317993

# %%
from sklearn.linear_model import Lasso

alpha = 1.0
lasso_model = Lasso(alpha = alpha)

# Entrenamos el modelo
lasso_model.fit(X_train, y_train)

# Evaluamos el rendimiento del modelo en los datos de prueba
score = lasso_model.score(X_test, y_test)
print("Coefficients:", lasso_model.coef_)
print("R2 score:", score)
# Out:
# Coefficients: [-5.29763849e-02  2.40140024e-02 -1.42797028e-02  8.74330286e+00
#  -4.62851881e-02  3.91376774e+00 -1.57920379e-02  3.73864906e+01
#   2.30780977e-03 -2.14011460e+00  1.21407537e-01 -2.49806391e+01
#   3.24263946e-02  8.93362031e+00 -5.87827418e-02  1.32567735e+01
#   1.42276005e-01 -5.90727450e+01  1.17413055e-01 -4.77217265e+01
#  -2.13814870e-02  1.51680927e+01 -2.69914896e-02  1.92068942e+01
#   2.52165562e-03  6.63349326e+00 -3.27978083e-02  4.54145260e+01
#   1.07045288e-01  2.18012220e+00 -7.88908562e-02  1.53434094e+01
#   7.32894008e-03  5.13736069e-02  1.68626257e-02  0.00000000e+00
#   0.00000000e+00 -5.17227728e+00  1.11541250e+01 -2.71181756e+00
#  -0.00000000e+00 -1.66869330e-02  3.12212830e-02 -5.71166449e-03
#   5.86546902e-03  9.61232408e+00 -6.39812676e+00  4.63634289e+00
#  -4.58755888e+00  6.99786731e-02 -2.73373532e+01  5.58121399e+00
#  -2.54935502e+00 -6.93455874e-02  3.77709437e-03 -6.87860020e-03
# ...

# %%
from pickle import dump
# from pickle import dump is a Python statement that imports the dump function from the pickle module.
# pickle is a module in Python that provides functions for serializing and deserializing Python objects. The dump function is used to serialize (i.e., convert into a byte stream) a Python object and write it to a file.

dump(lasso_model, open("../models/lasso_alpha-1.0.sav", "wb"))

# %%
import pickle

# Load the model back into memory using pickle.load
with open("../models/lasso_alpha-1.0.sav", "rb") as file:
    loaded_model = pickle.load(file)

# %%
loaded_model
# Out:
# Lasso()
